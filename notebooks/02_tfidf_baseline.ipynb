# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from pathlib import Path

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    classification_report,
    confusion_matrix
)

# %%
DATA_DIR = Path("../data/raw")

TRAIN_PATH = DATA_DIR / "train.csv"
TEST_PATH = DATA_DIR / "test.csv"

# %%
train_df = pd.read_csv(
    TRAIN_PATH,
    nrows=50000
)

test_df = pd.read_csv(
    TEST_PATH,
    nrows=10000
)

print("Train:", train_df.shape)
print("Test :", test_df.shape)
# Out:
# Train: (50000, 3)
# Test : (10000, 3)

# %%
train_df = train_df.rename(columns={
    "class_index": "label",
    "review_title": "title",
    "review_text": "text"
})

test_df = test_df.rename(columns={
    "class_index": "label",
    "review_title": "title",
    "review_text": "text"
})

# %%
train_df["label"] = train_df["label"].map({
    1: 0,
    2: 1
})

test_df["label"] = test_df["label"].map({
    1: 0,
    2: 1
})

# %%
train_df["text"] = (
    train_df["title"].fillna("") + " " +
    train_df["text"].fillna("")
).str.strip()

test_df["text"] = (
    test_df["title"].fillna("") + " " +
    test_df["text"].fillna("")
).str.strip()

# %%
X_train = train_df["text"]
y_train = train_df["label"]

X_test = test_df["text"]
y_test = test_df["label"]

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (50000,)
# (50000,)
# (10000,)
# (10000,)

# %%
tfidf = TfidfVectorizer(
    max_features=50000,
    ngram_range=(1, 2),
    min_df=2,
    max_df=0.95,
    sublinear_tf=True
)

# %%
X_train_tfidf = tfidf.fit_transform(X_train)

X_test_tfidf = tfidf.transform(X_test)

print("Train TF-IDF shape:", X_train_tfidf.shape)
print("Test TF-IDF shape :", X_test_tfidf.shape)
# Out:
# Train TF-IDF shape: (50000, 50000)
# Test TF-IDF shape : (10000, 50000)

# %%
model = LogisticRegression(
    max_iter=1000,
    n_jobs=-1
)

model.fit(X_train_tfidf, y_train)
# Out:
# c:\Users\DELL\OneDrive\Desktop\ReviewSense\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1457: FutureWarning: 'n_jobs' has no effect since 1.8 and will be removed in 1.10. You provided 'n_jobs=-1', please leave it unspecified.
#   warnings.warn(msg, category=FutureWarning)
# LogisticRegression(max_iter=1000, n_jobs=-1)

# %%
y_pred = model.predict(X_test_tfidf)

# %%
y_prob = model.predict_proba(X_test_tfidf)[:, 1]

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print(f"Accuracy : {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall   : {recall:.4f}")
print(f"F1 Score : {f1:.4f}")
# Out:
# Accuracy : 0.9081
# Precision: 0.9058
# Recall   : 0.9159
# F1 Score : 0.9108

# %%
print(
    classification_report(
        y_test,
        y_pred,
        target_names=["Negative", "Positive"]
    )
)
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.91      0.90      0.91      4875
#     Positive       0.91      0.92      0.91      5125
#
#     accuracy                           0.91     10000
#    macro avg       0.91      0.91      0.91     10000
# weighted avg       0.91      0.91      0.91     10000

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(6, 5))

sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    xticklabels=["Negative", "Positive"],
    yticklabels=["Negative", "Positive"]
)

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("TF-IDF + Logistic Regression Confusion Matrix")

plt.show()

# %%
pip install joblib
# Out:
# Requirement already satisfied: joblib in c:\Users\DELL\OneDrive\Desktop\ReviewSense\.venv\Lib\site-packages (1.5.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import joblib

joblib.dump(tfidf, "../models/tfidf_vectorizer.pkl")
joblib.dump(model, "../models/logistic_regression.pkl")

print("Baseline model saved! ✅")
# Out:
# Baseline model saved! ✅
